# %% [markdown]
# <a href="https://colab.research.google.com/github/g9772690/KTL_python_basic/blob/main/KTL_NumPy_%EC%9B%90%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **파이썬 빅데이터 분석**
#
# *   빅데이터 분석을 위한 라이브러리
#
# > * NumPy : 과학 계산 및 수학 계산
# > * pandas : 데이터 처리 및 분석
# > * matplotlib : 데이터 시각화
# > * seaborn : 데이터 시각화
# > * Bokeh : 큰 데이터 세트나 스트리밍 데이터 세트를 처리하는 대화형 시각화 라이브러리
# > *  plotly : 오픈 소스인 대화형의 고품질 도면 및 그래프 출판을 지원하는 그래픽 라이브러리
# > * NLTK : 자연어 처리
# > * SciPy : 신호 처리, 최적화, 과학계산 및 통계 처리
# > * BeautifulSoup : 웹 크롤링 및 데이터 수집
# > * TensorFlow : 머신러닝 및 딥러닝
# > * Keras : 신경망 라이브러리 및 딥러닝
# > * scikit-learn : 머신러닝 및 데이터 마이닝
# > * PyTorch : GUI 로 처리하는 신경망 모델링
# > * SpaCy : 대규모 텍스트 정보 수집 및 분석, 딥러닝 지원

# %% [markdown]
# *   기초적 용어 정리
#
# > * 객체(object)와 클래스 : 클래스는 특정 기능을 수행하는 코드를 블록으로 구성한 것이며, 객체는 클래스로부터 만들어진다.
# > * 인스턴싱(instancing) : 사용자가 클래스안에 있는 메소드나 속성을 가져다 사용하기 위해서는 객체를 클래스로부터 만든 후 가능하다. 객체를 생성하는 과정을 객체화라고 한다.
# > * 모듈(module) : 모듈은 클래스, 변수, 메소드 및 실행할 수 있는 코드에 대한 정의나 의미를 포함하는 하나의 파일 또는 패키지를 의미한다. 모듈을 이용하기 위해서는 import 문을 사용해야 한다.
# > * 함수와 메소드 : 혼용해서 사용하지만, 클래스에서는 메소드, 모듈에서는 함수라는 용어를 사용한다.
# > * 노트북 : 파이썬에 강력한 기능을 가진 웹 인터페이스를 제공하며, 일반적으로 주피터 노트북이라고 불리우며, 아나콘다를 통해 내려받을 수 있다.

# %% [markdown]
# **NumPy**
#   - NumPy(Nuumerical Python)는 C언어로 구현된 파이썬 라이브러리로써, 선형대수 기반의 프로그램을 쉽게 만들수 있게끔 지원하는 라이브러리이다.
#   - 다차원 배열 자료구조인 ndarray(c 언어로 구성되어 있어 파이썬의 리스트보다 빠름, 전체 데이터를 한 묶음으로 처리)를 지원하며 루프를 쓰지않고 대량 데이터의 배열연산을 가능하게 하므로 빠른 배열 연산속도를 보인다.
#     - ndarray의 장점
#       1. ndarray 는 C 언어에 기반한 배열 구조이므로 메모리를 적게 차지하고 속도가 빠르다.
#       2. ndarray 를 사용하면 배열과 배열 간에 수학적인 연산을 적용할 수 있다.
#       3. ndarray 는 고급 연산자와 풍부한 함수들을 제공한다.
#     - 예를 들어서 정수들의 2차원 배열(테이블)을 넘파이를 이용해서 생성할 수 있다. 배열의 각 요소는 인덱스(index)라고 불리는 정수들로 참조되며, 넘파이에서 차원은 축(axis=0,1...)이라고도 한다.
#   - ndarray는 numpy 의 기본 데이터 타입이며, 숫자, 문자열, 불 값등 모두 가능하지만, ndarray내의 데이터 타입은 연산의 특성상 같은 데이터 타입만 가능하다.
#   - 또한 이는 데이터분석을 할 때 사용되는 라이브러리인 pandas와 matplotlib의 기반으로 사용되기도 한다.
#   - 기존에 python을 미리 설치하였고 path 설정이 되어있다면 pip 명령어를 이용하여 numpy를 설치할 수 있다.
#   - Command창에서  >pip install numpy  실행
#   - https://numpy.org/

# %% [markdown]
# *   넘파이 배열 생성
#   - 리스트, 튜플등 다른 파이썬 자료 구조에서 변환
#   - arange(), ones(), zeros(), linspace() 등 고유한 배열 생성함수 사용
#   - 문자열이나 버퍼를 통한 바이트 스트림 데이터인 raw bytes 에서 배열 생성
#   - random() 함수와 같은 특수한 라이브러리 함수 사용

# %%
                             #넘파이 사용을 위해 넘파이 패키지 호출(numpy 의 별칭은 np)

# %% [markdown]
# *   넘파이 배열의 특징
#  - 배열은 요소를 연산하고 저장하기에 효율적이다. 넘파이 배열을 만드는 이유는 논리적이고 통계적인 연산과 푸리에 변환같은 연산을 매우 효율적으로 처리할 수 있기 때문이다.
#   - 넘파이 배열은 파이썬의 리스트보다 많은 데이터를 처리할 수 있으며, 리스트에서 사용할 수 없는 기능이나 방법들을 다양한 라이브러리를 이용해 처리할 수 있다.
#     - 넘파이에서는 벡터(1차원 배열)와 매트릭스(2차원 배열)를 배열이라고 한다.

# %% [markdown]
# *   파이썬 유사 배열 객체를 넘파이 배열로 변환
#   - 파이썬에는 배열이 없으며, 리스트를 이용해 유사배열(array-like)을 만든다.
#   - 넘파이에서는 numpy.array()함수를 이용해 리스트로 배열을 생성하며, 이 함수에 매개변수로 입력되는 리스트를 유사배열이라 한다.
#   - 이렇게 만들어진 넘파이 배열을 ndarray 객체라고 한다.
#   - 넘파이 배열 객체는 , 가 없으며, 리스트는 , 로 원소들 구분

# %% [markdown]
# *   ndarray 객체의 속성

# %%
# ndarray 객체의 속성

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   넘파이 배열 생성함수
#   - zeros() 함수 : 모든 값이 0으로 채워지는 배열을 생성
#   - ones() 함수 : 모든 값이 1로 채워지는 배열을 생성
#   - empty() 함수 : 초기화되지 않는 임의의 값들을 생성하며 초기화 함수 중 가장 빠르게 처리된다.
#   - eye() 함수 : 대각선에는 1, 그 밖의 위치에 0값을 가지는 배열을 생성하며 실행결과는 2차원 배열이다.
#   - linspace() 함수 : 명시된 간격으로 균등하게 분할된 값을 반환한다.

# %% [markdown]
# *   넘파이 배열 생성함수
#   - arange() 함수 : [시작, 끝)인 범위값 형태의 배열을 생성, 파이썬의 range 함수와 유사
#   - reshape() 함수 : 데이터를 변경하지 않고 새로운 shape 의 배열을 생성(예, 1차원 배열을 2차원으로)
#     - ndarray.reshape(-1) : 다차원 배열을 1차원으로
#     - ndarray.reshape(-1,1) : ndarray에 대해 행은 모르고 열은 1개인 배열로 재생성

# %% [markdown]
#     - 1차원 배열 : 행(row)
#     - 2차원 배열 : 행(row) / 열(column)
#     - 3차원 배열 : 면(depth) / 행(row) / 열(column)

# %% [markdown]
# *   넘파이 ndarray 클래스
#   - N-dimensional Array의 약자이다. 이름 그대로 1차원 배열 이외에도 2차원 배열, 3차원 배열 등 같은 타입의 요소들을 모아 놓은 다차원 배열 자료 구조(객체)이다. 2차원 배열은 행렬(matrix)이라고 하는데 행렬에서는 가로줄을 행(row)이라고 하고 세로줄을 열(column)이라고 부른다.
#   - 리스트의 리스트(list of list)를 이용하면 2차원 배열을 생성할 수 있다. 안쪽 리스트의 길이는 행렬의 열의 수 즉, 가로 크기가 되고 바깥쪽 리스트의 길이는 행렬의 행의 수, 즉 세로 크기가 된다. 예를 들어 2개의 행과 3개의 열을 가지는 2 x 3 배열은 다음과 같이 만든다.

# %% [markdown]
#   - ndarray는 인접하는 블록의 C(행) 우선 또는 F(열) 우선 형태로 부호화되어 저장된다. C는 C 언어, F는 FORTRAN

# %% [markdown]
# *   넘파이 배열의 데이터 타입
#   - numpy.dtype 클래스 : 스칼라인 배열 요소를 반환한다. 넘파이는 스칼라 데이터의 다양한 타입이 존재(예 int_(int8, int16, int32) , float_(float16, float32, float64) , complex_ , bytes_ , unicode_)

# %% [markdown]
# *   배열의 인덱싱과 슬라이싱
#   - 일차원 배열의 인덱싱은 리스트의 인덱싱과 같다.
#   - 다차원 배열일 때는 콤마(comma ,)를 사용하여 접근할 수 있다. 콤마로 구분된 차원을 축(axis)이라고도 한다. 그래프의 x축과 y축을 떠올리면 된다.
#   - 인덱싱의 기본 구문은 i:j:k 이다. i는 시작 인덱스, j는 종료 인덱스, k는 step으로 간격을 의미하며, k의 값이 없으면 1로 간주한다.

# %% [markdown]
# ![배열슬라이싱유형.png](data:image/png;base64,...)

# %% [markdown]
# *   기본 인덱싱과 슬라이싱
#   - 기본 인덱싱 처리로 생성되는 모든 배열은 항상 원본 배열의 뷰(view)이다.
#   - 뷰는 원본배열 객체를 인덱싱하여 자른 후 생성된 배열을 의미한다. 뒷 부분에서 다시 살펴본다.

# %% [markdown]
# *   배열 인덱싱
#   - 넘파이 배열 객체의 또다른 강력한 기능은 배열 인덱싱(array indexing) 방법이다. 인덱싱이라는 이름이 붙었지만 사실은 데이터베이스의 질의(Query) 기능을 수행한다.
#   - 배열 인덱싱에서는 대괄호안의 인덱스 정보로 숫자나 슬라이스가 아니라 위치 정보를 나타내는 또 다른 ndarray 배열을 받을 수 있다. 여기에서는 이 배열을 편의상 인덱스 배열이라고 부르겠다. 배열 인덱싱의 방식에는 불리언(Boolean) 배열 방식과 정수 배열 방식 두가지가 있다.
#   - 먼저 불리안 배열 인덱싱 방식은 인덱스 배열의 원소가 True, False 두 값으로만 구성되며 인덱스 배열의 크기가 원래 ndarray 객체의 크기와 같아야 한다.
#   - 예를 들어 다음과 같은 1차원 ndarray에서 짝수인 원소만 골라내려면 짝수인 원소에 대응하는 인덱스 값이 True이고 홀수인 원소에 대응하는 인덱스 값이 False인 인덱스 배열을 넣으면 된다.

# %% [markdown]
#   - 조건문 연산을 사용하면 다음과 같이 간단히 쓸 수 있다.

# %% [markdown]
#   - 정수 배열 인덱싱에서는 인덱스 배열의 원소 각각이 원래 ndarray 객체 원소 하나를 가리키는 인덱스 정수이여야 한다. 예를 들어 1차원 배열에서 홀수번째 원소만 골라내는 것은 다음과 같다

# %% [markdown]
#   - 이 때는 배열 인덱스의 크기가 원래의 배열 크기와 달라도 상관없다. 같은 원소를 반복해서 가리키는 경우에는 배열 인덱스가 원래의 배열보다 더 커지기도 한다.

# %% [markdown]
#   - 배열 인덱싱은 다차원 배열의 각 차원에 대해서도 할 수 있다.

# %% [markdown]
#   - 인덱스를 반환하는 numpy.nonzero() , numpy.transpose() 함수
#     - numpy.nonzero() 함수는 0이 아닌 요소의 인덱스들을 반환하며 numpy.ndarray.nonzero 를 실행한 것과 같은 결과를 반환한다.
#     - 즉 각 배열의 차원에서 0이 아닌 요소의 인덱스를 포함하는 튜플을 반환한다.

# %% [markdown]
#   - 아래는 배열의 요소가 0이 아닌 값들을 정렬한다. 그리고 축을 바꾸는 전치함수 numpy.transpose()를 사용하면 배열에서 0이 아닌 값을 나타내는 인덱스들을 그룹으로 처리할 수 있다.

# %% [markdown]
#   - nonzero() 함수에 불리언 조건을 적용해 True인 인덱스를 반환하게 할 수 있다.

# %% [markdown]
#   - numpy.transpose() 함수는 배열의 축을 변환하여 뷰를 반환한다. 아래 예제의 경우, 2차원 배열 arr을 전치하면 행이 열로, 열이 행으로 축이 변환된다.

# %% [markdown]
#   - 1차원 배열은 전치하면 원본 배열과 같은 뷰를 반환한다.
#   - numpy.ndarray.T 속성을 이용하는 arr.T 방식, np.transpose(arr) 방식, arr.transpose() 함수를 사용하는 3가지 방식으로 전치 처리를 할 수 있다.

# %% [markdown]
#   - 유니버셜 함수 : 스칼라로 연산하는 수학적 함수들. 그 중에 사인 함수 이용해서 간단하게 그래프로 그려본다.

# %% [markdown]
#   - 뷰
#     - 넘파이 배열의 뷰(view)는 배열 데이터를 보는 하나의 방법이다.
#     - 뷰는 원래 배열에서 슬라이싱하는 슬라이스 뷰나 dtype을 변경하는 dtype 뷰로 생성할 수 있다.

# %% [markdown]
#   - 복사 : 다음 예제의 배열 객체 arr을 불리언으로 인덱싱하면 arr 중 해당하는 부분의 복사를 반환한다. 복사는 arr1의 요소를 변경하더라도 원본배열인 arr의 요소에는 변화가 없다.

# %% [markdown]
#   - 그러나 같은 원본 배열에 슬라이싱을 실행해 다른 값을 동적 할당하면 원본배열인 arr의 요소가 변경된다.

# %% [markdown]
#   - 브로드캐스팅
#     - 벡터(또는 행렬)끼리 덧셈 혹은 뺄셈을 하려면 두 벡터(또는 행렬)의 크기가 같아야 한다. 넘파이에서는 서로 다른 크기를 가진 두 배열의 사칙 연산도 지원한다. 이 기능을 브로드캐스팅(broadcasting)이라고 하는데 크기가 작은 배열을 자동으로 반복 확장하여 크기가 큰 배열에 맞추는 방벙이다.
#     - 즉, 브로드캐스팅(Broadcasting)은 모양이 다른 배열들 간의 연산이 어떤 조건을 만족했을 때 가능해지도록 배열을 자동적으로 변환하는 것이라고 정의할 수 있다.
#     - 두 배열을 연산한 결과의 크기는 입력 배열들 중 최대 크기를 가진 차원을 따라 정해진다.
#     - 브로드캐스팅이 일어날 수 있는 조건은 다음과 같다.
#       - 차원의 크기가 1일때 가능하다. 두 배열 간의 연산에서 최소한 하나의 배열의 차원이 1이라면(0번 축이든 1번 축이든; 1행이든 1열이든) 가능하다.
#       - 차원의 짝이 맞을 때 가능하다.차원에 대해 축의 길이가 동일하면 브로드캐스팅이 가능하다.

# %% [markdown]
# ![브로드캐스팅.png](data:image/png;base64,...)

# %% [markdown]
#   - numpy.newaxis 적용
#     - 넘파이 배열객체의 차원을 늘려줌. 1차원 배열을 2차원 열벡터나 행벡터로 변환할 수 있다.

# %% [markdown]
#   - 다음은 newaxis 연산자를 이용해 1차원 shape (4,)인 배열 arr1 을 2차원 shape(4x1)로 만들어 shape (3,)인 arr2와 덧셈 연산을 할 수 있도록 한 예제이다.

# %% [markdown]
#   - 브로드 캐스팅 연산
#     - 크기가 서로 다른 배열을 크기가 같아지도록 확장 개념을 사용해 브로드캐스팅으로 변환하면 크기가 다른 배열간 연산을 실행할 수 있다. 입력 데이터보다 더 많은 출력을 얻는 문제를 해결할 때 이 방법을 사용할 수 있다.
#     - 브로드캐스팅은 이미지 처리 및 관리분야에도 적용할 수 있다.
#     - 아래 예제에서는 1차원 배열 arr1을 2차원 배열로 변환한 후 arr2와 브로드캐스팅 연산하여 제곱근을 취하고 그림을 나타낸 것이다.

# %% [markdown]
#   - 배열 조작
#     - 배열을 이어 붙이고 스택으로 배치
#       - 배열을 이어 붙일 때 numpy.concatenate() 함수를 사용하며, 이 함수는 설정한 축을 따라 배열을 이어 붙인다.
#       - numpy.vstack() 함수는 행 단위로 수직으로 배열을 쌓는다. 따라서 axis=0 을 설정한 이어붙이기와 동일하다.
#       - numpy.hstack() 은 열단위로 수평으로 배열을 쌓는다.

# %% [markdown]
#   - 배열 순서 정렬

# %% [markdown]
#   - numpy.argsort 는 배열을 정렬할 인덱스를 반환한다. 다음은 1차원 배열을 정렬한 예제이다.
#   - 아래는 2차원 배열을 정렬한 예제이다.

# %% [markdown]
#   - numpy.lexsort 는 아래 예제를 기준으로 arr2 를 먼저 정렬하고 그 다음 arr1 을 정렬하며, arr2 요솟값들이 같으면 arr1을 기준으로 정렬한다.

# %% [markdown]
#   - numpy.histogram 은 데이터 세트의 히스토그램을 그린다.

# %% [markdown]
#   - 차원축소연산
#     - 행렬의 하나의 행에 있는 원소들을 하나의 데이터 집합으로 보고 그 집합의 평균을 구하면 각 행에 대해 하나의 숫자가 나오게 된다.
#     - 예를 들어 10x5 크기의 2차원 배열에 대해 행-평균을 구하면 10개의 숫자를 가진 1차원 벡터가 나오게 된다. 이러한 연산을 차원 축소(dimension reduction) 연산이라고 한다.
#     - 넘파이는 다음과 같은 차원 축소 연산 명령 혹은 메서드를 지원한다.
#       - 최대/최소: min, max, argmin, argmax
#       - 통계: sum, mean, median, std, var
#       - 불리언: all, any

# %% [markdown]
#   - 연산의 대상이 2차원 이상인 경우에는 어느 차원으로 계산을 할 지를 axis 인수를 사용하여 지시한다. axis=0인 경우는 열 연산, axis=1인 경우는 행 연산이다. 디폴트 값은 axis=0이다. axis 인수는 대부분의 차원 축소 명령에 적용할 수 있다.

# %% [markdown]
#   - 난수 발생 - random 클래스 사용
#     - random.rand()  :  0~1 사이의 실수값 (균등분포)
#     - random.randint(a,b)     : a~b 사이의 정수값
#     - random.randn()   : N(0,1)의 정규분포값
#     - random.normal(a,b,c)   :  N(a, b^2) 난수 c개 생성
#     - random.random_sample()    : 연속형 균일분포(continuous uniform distribution)를 이용하여 0 이상 1 미만인 범위에서 샘플링된 임의의 실수를 반환합니다.
#     - random.choice()   :  특정 배열(행렬)에서 특정 값을 추출할 때
#     - random.seed()   :  씨드값 설정 -> 동일한 값이 난수 발생됨
#     - random.shuffle() : 데이터의 순서를 바꾼다.
#     - np.around(data) : 소수점 자리 수를 반올림해서 정수로 만들어줌
#     - np.round(data, decimals) :  원하는 소수점 자리수에서 반올림
#     - np.ceil(data) : 소수점 자리 수를 올림해서 정수로 만들어줌
#     - np.floor(data) : 소수점 자리 수를 버림해서 정수로 만들어줌
